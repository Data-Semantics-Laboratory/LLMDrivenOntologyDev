# %%
# Clean up wikitext (remove citations, external links, etc.) also fix the headings
import os

folder_path = "./"

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        # Do something with the file
        with open(file_path, 'r') as read:
            lines = read.readlines()
            for line in lines:
                if line.strip().startswith("=") and line.strip().endswith("="):
                    print(line)
        with open(file_path, 'w') as write:
            for line in lines:
                if line.strip().startswith("=") and line.strip().endswith("="):
                    write.write(line.replace("=", "").strip() + ": \n")
                else:
                    write.write(line)
                #if "== See also ==" in line or "== External links ==" in line or "== References ==" in line or "== Further reading ==" in line or "== Notes ==" in line or "== Sources ==" in line or "== Footnotes ==" in line or "== Footnotes and Citations ==":
                #    break
                #print(line)
                #if line.startswith("\n"):
                #    continue
                #elif line.startswith(" "):
        #                    continue
                #    file.write(line.strip())
                #else:
        #                print(line)
        #            line = line.replace("== ", "= ").replace(" ==", " =")
        #            file.write(line)
        #            if line.startswith("= "):
        #                print(line)
# Out:
# = Early life =
#
# = Africa =
#
# = Later life =
#
# = Legacy =
#
# = Early life =
#
# = American Revolution =
#
# == Service under William Whipple ==
#
# == Freedom Petition ==
#
# == After the War ==
#
# = Death and legacy =
#
# = Biography =
#
# = The Jerry Rescue =
#
# = Family =
#
# = Legacy =
#
# = Writing =
#
# = American Revolutionary War =
#
# == 2nd Connecticut ==
#
# == Valley Forge, Pennsylvania ==
#
# == Battle of Monmouth ==
#
# = Private life =
#
# = Descendants =
#
# = Early and family life =
#
# = Journalism and politics =
#
# = Ministry =
#
# = Death and legacy =
#
# = Major works =
#
# = Early life =
#
# = Conversion to the LDS faith =
#
# == Priesthood ordination and church participation ==
#
# === Patriarchal blessing ===
#
# == Mission to Upper Canada ==
#
# = Time in Nauvoo, temple building and civil marriage =
#
# == Marriage ==
#
# = Migration and later years in Utah =
#
# = Disputes over priesthood =
#
# == Meeting in Cincinnati, 1843 ==
#
# ...
